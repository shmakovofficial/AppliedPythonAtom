# %%
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# Возьмем датасет [отсюда](https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset).

# %%
df = pd.read_csv("./data/framingham.csv")

# %%
# посмотрим на sample датасета
df.sample(5)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 1977     0   64        3.0              0         0.0     0.0
# 1060     0   55        2.0              1         3.0     0.0
# 2414     0   65        1.0              0         0.0     0.0
# 3974     0   64        1.0              0         0.0     0.0
# 592      1   39        4.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 1977                0             0         0    330.0  108.0   82.0  23.09
# 1060                0             0         0    252.0  108.5   63.5  25.23
# 2414                0             0         0    212.0   94.0   62.0  25.83
# 3974                0             1         1    262.0  147.0   90.0  26.51
# 592                 0             0         0    232.0  115.0   72.5  30.22
#
#       heartRate  glucose  TenYearCHD
# 1977       85.0     80.0           0
# 1060       80.0    121.0           0
# ...

# %%
# посмотрим на признаки и инфу о них
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
# посмотрим, есть ли пропущенные значения
df.isna().sum()/len(df)
# Out:
# male               0.000000
# age                0.000000
# education          0.024764
# currentSmoker      0.000000
# cigsPerDay         0.006840
# BPMeds             0.012500
# prevalentStroke    0.000000
# prevalentHyp       0.000000
# diabetes           0.000000
# totChol            0.011792
# sysBP              0.000000
# diaBP              0.000000
# BMI                0.004481
# heartRate          0.000236
# glucose            0.091509
# TenYearCHD         0.000000
# dtype: float64

# %%
# что будем делать с NaN-ами?
# что вообще можно с ними делать? (3 варианта)
df.fillna(df.mean())
# Out:
#       male  age  education  currentSmoker  cigsPerDay    BPMeds  \
# 0        1   39        4.0              0         0.0  0.000000
# 1        0   46        2.0              0         0.0  0.000000
# 2        1   48        1.0              1        20.0  0.000000
# 3        0   61        3.0              1        30.0  0.000000
# 4        0   46        3.0              1        23.0  0.000000
# 5        0   43        2.0              0         0.0  0.000000
# 6        0   63        1.0              0         0.0  0.000000
# 7        0   45        2.0              1        20.0  0.000000
# 8        1   52        1.0              0         0.0  0.000000
# 9        1   43        1.0              1        30.0  0.000000
# 10       0   50        1.0              0         0.0  0.000000
# 11       0   43        2.0              0         0.0  0.000000
# 12       1   46        1.0              1        15.0  0.000000
# 13       0   41        3.0              0         0.0  1.000000
# ...

# %%
# посмотрим на распределения значений признаков (и таргета)
sns.pairplot(df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# посмотрим на корреляцию между признаками
sns.heatmap(df.corr())

# %%
# посмотрим на "взаимодействия" признаков

# %%
# что такое boxplot?
# посмотрим на него (них)
sns.boxplot(y=df['age'],x=df['TenYearCHD'], orient='v')

# %%
# разделим данные на train и test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(['TenYearCHD'],axis=1),df['TenYearCHD'], test_size=0.33,random_state=42)

# %%
# выполним нормализацию (зачем она, кстати, нужна)?
features=['male','currentSmoker','education','prevalentStroke','prevalentHyp','diabetes']
from sklearn.preprocessing import StandardScaler
standart=StandardScaler()
X_train_quant = standart.fit_transform(X_train[list(set(X_train.columns)-set(features))])
X_test_quant = standart.fit_transform(X_test[list(set(X_test.columns)-set(features))])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# обучим логистическую регресиию

# %%
# оценим качество
